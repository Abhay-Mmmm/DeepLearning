# %%
import sys
!"{sys.executable}" -m pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\abhay\onedrive\desktop\programs\deeplearning\tf_dml_env\lib\site-packages (from scikit-learn) (1.24.4)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.15.3 threadpoolctl-3.6.0

# %%
import tensorflow_hub as hub
import tensorflow_text as text
import tensorflow as tf

# %%
import pandas as pd

df = pd.read_csv("spam.csv")
df = df.drop(columns=['index'], errors='ignore')
df.columns = ['Category', 'Message']

df.head(3)
# Out:
#   Category                                            Message
# 0      ham                      Ok lar... Joking wif u oni...
# 1     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2      ham  U dun say so early hor... U c already then say...

# %%
df_spam = df[df['Category']=='spam']
df_spam.shape
# Out:
# (17, 2)

# %%
df_ham = df[df['Category']=='ham']
df_ham.shape
# Out:
# (83, 2)

# %%
df_ham_downsampled = df_ham.sample(df_spam.shape[0])
df_ham_downsampled.shape
# Out:
# (17, 2)

# %%
df_balanced = pd.concat([df_spam, df_ham_downsampled])
df_balanced.shape
df_balanced.head(3)
# Out:
#   Category                                            Message
# 1     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 4     spam  FreeMsg Hey there darling it's been 3 week's n...
# 7     spam  WINNER!! As a valued network customer you have...

# %%
df_balanced['Category'] = df_balanced['Category'].map({'spam' : 1,'ham': 0})
df_balanced.head(3)
# Out:
#    Category                                            Message
# 1         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 4         1  FreeMsg Hey there darling it's been 3 week's n...
# 7         1  WINNER!! As a valued network customer you have...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df_balanced['Message'],df_balanced['Category'])

# %%
bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
#       2 bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow_hub\keras_layer.py:165, in KerasLayer.__init__(self, handle, trainable, arguments, _sentinel, tags, signature, signature_outputs_as_dict, output_key, output_shape, load_options, **kwargs)
#     161   self._output_shape = data_structures.NoDependency(
#     162       _convert_nest_to_shapes(output_shape))
#     164 self._load_options = load_options
# --> 165 self._func = load_module(handle, tags, self._load_options)
#     166 self._is_hub_module_v1 = getattr(self._func, "_is_hub_module_v1", False)
#     168 # Update with the defaults when using legacy TF1 Hub format.
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow_hub\keras_layer.py:467, in load_module(handle, tags, load_options)
#     465     except ImportError:  # Expected before TF2.4.
#     466       set_load_options = load_options
# --> 467 return module_v2.load(handle, tags=tags, options=set_load_options)
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow_hub\module_v2.py:126, in load(handle, tags, options)
#     123   obj = tf.compat.v1.saved_model.load_v2(
#     124       module_path, tags=tags, options=options)
#     125 else:
# --> 126   obj = tf.compat.v1.saved_model.load_v2(module_path, tags=tags)
#     127 obj._is_hub_module_v1 = is_hub_module_v1  # pylint: disable=protected-access
#     128 return obj
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\saved_model\load.py:800, in load(export_dir, tags, options)
#     798 if isinstance(export_dir, os.PathLike):
#     799   export_dir = os.fspath(export_dir)
# --> 800 result = load_partial(export_dir, None, tags, options)["root"]
#     801 return result
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\saved_model\load.py:930, in load_partial(export_dir, filters, tags, options)
#     928 with ops.init_scope():
#     929   try:
# --> 930     loader = Loader(object_graph_proto, saved_model_proto, export_dir,
#     931                     ckpt_options, options, filters)
#     932   except errors.NotFoundError as err:
#     933     raise FileNotFoundError(
#     934         str(err) + "\n You may be trying to load on a different device "
#     935         "from the computational device. Consider setting the "
#     936         "`experimental_io_device` option in `tf.saved_model.LoadOptions` "
#     937         "to the io_device such as '/job:localhost'.")
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\saved_model\load.py:192, in Loader.__init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, save_options, filters)
#     189 self._load_all()
#     191 if not save_options.experimental_skip_checkpoint:
# --> 192   self._restore_checkpoint()
#     193 for node in self._nodes:
#     194   if isinstance(node, resource.CapturableResource):
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\saved_model\load.py:510, in Loader._restore_checkpoint(self)
#     508   load_status.assert_nontrivial_match()
#     509 else:
# --> 510   load_status = saver.restore(variables_path, self._checkpoint_options)
#     511   load_status.assert_existing_objects_matched()
#     512 ckpt = load_status._checkpoint
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\checkpoint\checkpoint.py:1495, in TrackableSaver.restore(self, save_path, options)
#    1484 object_graph_proto.ParseFromString(object_graph_string)
#    1485 checkpoint = _CheckpointRestoreCoordinator(
#    1486     object_graph_proto=object_graph_proto,
#    1487     save_path=save_path,
#    (...)
#    1492     options=options,
#    1493     saveables_cache=self._saveables_cache)
#    1494 restore_lib.CheckpointPosition(
# -> 1495     checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1497 # Attached dependencies are not attached to the root, so should be restored
#    1498 # separately.
#    1499 if self._graph_view.attached_dependencies:
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\checkpoint\restore.py:55, in CheckpointPosition.restore(self, trackable)
#      51 with ops.init_scope():
#      52   if self.bind_object(trackable):
#      53     # This object's correspondence with a checkpointed object is new, so
#      54     # process deferred restorations for it and its dependencies.
# ---> 55     restore_ops = self._restore_descendants()
#      56     if restore_ops:
#      57       self._checkpoint.new_restore_ops(restore_ops)
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\checkpoint\restore.py:458, in CheckpointPosition._restore_descendants(self)
#     454   _queue_children_for_restoration(current_position, visit_queue)
#     455   _queue_slot_variables(current_position, visit_queue)
#     457 restore_ops.extend(
# --> 458     current_position.checkpoint.restore_saveables(tensor_saveables,
#     459                                                   python_positions,
#     460                                                   registered_savers))
#     461 return restore_ops
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\checkpoint\checkpoint.py:354, in _CheckpointRestoreCoordinator.restore_saveables(self, tensor_saveables, python_positions, registered_savers)
#     349 if tensor_saveables or registered_savers:
#     350   flat_saveables = saveable_object_util.validate_and_slice_inputs(
#     351       tensor_saveables)
#     352   new_restore_ops = functional_saver.MultiDeviceSaver(
#     353       flat_saveables,
# --> 354       registered_savers).restore(self.save_path_tensor, self.options)
#     355   if not context.executing_eagerly():
#     356     for name, restore_op in sorted(new_restore_ops.items()):
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\checkpoint\functional_saver.py:403, in MultiDeviceSaver.restore(self, file_prefix, options)
#     401   restore_ops = tf_function_restore()
#     402 else:
# --> 403   restore_ops = restore_fn()
#     405 return restore_ops
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\checkpoint\functional_saver.py:385, in MultiDeviceSaver.restore.<locals>.restore_fn()
#     383 for device, saver in sorted(self._single_device_savers.items()):
#     384   with ops.device(device):
# --> 385     restore_ops.update(saver.restore(file_prefix, options))
#     386 # Run registered restore methods after the default restore ops.
#     387 for _, (_, restore_fn) in self._registered_savers.items():
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\checkpoint\functional_saver.py:111, in _SingleDeviceSaver.restore(self, file_prefix, options)
#     108 restore_ops = {}
#     109 for saveable, restored_tensors in zip(self._saveable_objects,
#     110                                       structured_restored_tensors):
# --> 111   restore_ops[saveable.name] = saveable.restore(
#     112       restored_tensors, restored_shapes=None)
#     113 return restore_ops
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\training\saving\saveable_object_util.py:132, in ResourceVariableSaveable.restore(self, restored_tensors, restored_shapes)
#     130 restored_tensor = array_ops.identity(restored_tensor)
#     131 try:
# --> 132   assigned_variable = resource_variable_ops.shape_safe_assign_variable_handle(
#     133       self.handle_op, self._var_shape, restored_tensor)
#     134 except ValueError as e:
#     135   raise ValueError(
#     136       f"Received incompatible tensor with shape {restored_tensor.shape} "
#     137       f"when attempting to restore variable with shape {self._var_shape} "
#     138       f"and name {self.name}.") from e
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:309, in shape_safe_assign_variable_handle(handle, shape, value, name)
#     307   value_tensor = ops.convert_to_tensor(value)
#     308 shape.assert_is_compatible_with(value_tensor.shape)
# --> 309 return gen_resource_variable_ops.assign_variable_op(
#     310     handle, value_tensor, name=name)
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:146, in assign_variable_op(resource, value, validate_shape, name)
#     144   return _result
#     145 except _core._NotOkStatusException as e:
# --> 146   _ops.raise_from_not_ok_status(e, name)
#     147 except _core._FallbackException:
#     148   pass
#
# File ~\OneDrive\Desktop\Programs\DeepLearning\tf_dml_env\lib\site-packages\tensorflow\python\framework\ops.py:7209, in raise_from_not_ok_status(e, name)
#    7207 def raise_from_not_ok_status(e, name):
#    7208   e.message += (" name: " + name if name is not None else "")
# -> 7209   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: Multiple OpKernel registrations match NodeDef at the same priority '{{node AssignVariableOp}}': 'op: "AssignVariableOp" device_type: "GPU" constraint { name: "dtype" allowed_values { list { type: DT_INT64 } } } host_memory_arg: "resource"' and 'op: "AssignVariableOp" device_type: "GPU" constraint { name: "dtype" allowed_values { list { type: DT_INT64 } } } host_memory_arg: "resource"'
# 	 [[AssignVariableOp]] [Op:AssignVariableOp]
